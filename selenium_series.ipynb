# %%
## 패키지 선언
from selenium import webdriver
from bs4 import BeautifulSoup as BS
import pandas as pd

# %%
## 내가 조종할 크롬 노예 생성 
driver = webdriver.Chrome()

# %%
url ="https://www.disneyplus.com/ko-kr/series/53adf843-491b-40ae-9b46-bccbceed863b"

# %%
driver.get(url)

# %%
## 클릭에 필요한 패키지 선언
from selenium.webdriver.common.by import By

# 내가 클릭하고 싶은 위치를 selector로 Copy
target = "body > header > nav.nav.pre-sticky > ul > li > a"

## selector 로 복사해왔기 때문에 설정 , 위치에 요소를 찾고 클릭
driver.find_element(By.CSS_SELECTOR, target).click()

# %%
# 아이디와 비밀번호
email = "###"
password = "###"

# %%
# 아이디 양식 찾기
email_input = driver.find_element(By.ID, "email") 

# 아이디와 비밀번호 입력
email_input.send_keys(email)

#다음 클릭 
driver.find_element(By.CSS_SELECTOR, "#loginEmail > div:nth-child(4) > button").click()

# %%
# 비밀번호 양식 찾기
password_input = driver.find_element(By.ID, "password")  # 실제 비밀번호 입력 필드의 ID로 변경해 주세요

# 비밀번호 입력
password_input.send_keys(password)

# 로그인 클릭 
driver.find_element(By.CSS_SELECTOR, "#password-continue-login").click()

# %%
# 프로필 선택
driver.find_element(By.CSS_SELECTOR, "#remove-main-padding_index > div > div > section > ul > div:nth-child(1) > div > div").click()

# %%
import time

# 스크롤 계속 내리기
while True:
    # 현재 스크롤 높이 계산
    scroll_height = driver.execute_script("return document.body.scrollHeight")

    # 스크롤 내리기
    driver.execute_script(f"window.scrollTo(0, {scroll_height});")

    # 새로운 내용이 로드되길 기다림
    time.sleep(2)

    # 새로운 스크롤 높이 확인
    new_scroll_height = driver.execute_script("return document.body.scrollHeight")

    # 새로운 스크롤 높이가 이전과 동일하면 스크롤이 끝난 것으로 판단하고 종료
    if new_scroll_height == scroll_height:
        driver.execute_script("window.scrollTo(0,0);")
        break

# %%
displus_list= []

# %%
import re

pattern = r"시즌\s[0-9]+개"
for num in range(0,820):
    displus_dict={}
    print(num)
    bs = BS(driver.page_source)
    driver.find_element(By.CSS_SELECTOR, f"#section_index > article > div:nth-child(2) > div > div > div > div > div:nth-child({num})").click()

    time.sleep(3)
    ## 페이지 소스 
    bs2 = BS(driver.page_source)

    ## 포스터
    displus_dict['img'] = bs.findAll("div",class_="gv2-asset")[num-1].find("img")['src']

    ## 제목 
    displus_dict['title'] = bs.findAll("div",class_="sc-bdVaJa hRKcBi image-container")[num-1]['alt']
    
    ## 시즌 개수
    displus_dict['series'] = re.search(pattern, bs2.find("div", class_="sc-kDgGX gDKweb").find("span").text).group()

    try:
        ## 장르
        displus_dict['genre'] = bs2.findAll("div", class_="sc-AqAhp lhwxfs")[2].find("p", class_="body-copy margin--0 text-color--primary").text.replace("\u2060","")
    except:
        pass
    ## 줄거리 
    displus_dict['overview'] = bs2.find("p",class_="margin--0 body-copy body-copy--large text-color--primary").text

    ## 개봉연도
    displus_dict['open'] = bs2.findAll("div", class_="sc-AqAhp lhwxfs")[1].find("p", class_="body-copy margin--0 text-color--primary").text
    
    try:
        ## 출연
        displus_dict['actors'] = [x.text.replace(" ","") for x in bs2.find("div",class_="sc-exdmVY hWjZRq").findAll("p", class_="body-copy margin--0 text-color--primary")]
    except:
        pass

    ## 러닝타임
    displus_dict['runtime'] = bs2.findAll("div", class_="sc-AqAhp lhwxfs")[0].find("p", class_="body-copy margin--0 text-color--primary").text
    
    displus_list.append(displus_dict)
    driver.back()
     
    time.sleep(2)
# Out:
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# 599
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[15], line 8
#       6 print(num)
#       7 bs = BS(driver.page_source)
# ----> 8 driver.find_element(By.CSS_SELECTOR, f"#section_index > article > div:nth-child(2) > div > div > div > div > div:nth-child({num})").click()
#      10 time.sleep(3)
#      11 ## 페이지 소스
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#section_index > article > div:nth-child(2) > div > div > div > div > div:nth-child(650)"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102d63f48 chromedriver + 4226888
# 1   chromedriver                        0x0000000102d5c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001029a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001029dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102a12c58 chromedriver + 748632
# 5   chromedriver                        0x00000001029cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001029d0ef4 chromedriver + 478964
# 7   chromedriver                        0x0000000102d2559c chromedriver + 3970460
# 8   chromedriver                        0x0000000102d296f0 chromedriver + 3987184
# 9   chromedriver                        0x0000000102d2f5b4 chromedriver + 4011444
# 10  chromedriver                        0x0000000102d2a2fc chromedriver + 3990268
# 11  chromedriver                        0x0000000102d021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102d46088 chromedriver + 4104328
# 13  chromedriver                        0x0000000102d461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102d55f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x0000000189aa3fa8 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x0000000189a9eda0 thread_start + 8

# %%
display=pd.DataFrame(displus_list)

# %%
display
# Out:
#                                                    img               title  \
# 0    https://prod-ripcut-delivery.disney-plus.net/v...       101 달마시안 스트리트
# 1    https://prod-ripcut-delivery.disney-plus.net/v...          101마리 달마시안
# 2    https://prod-ripcut-delivery.disney-plus.net/v...                  24
# 3    https://prod-ripcut-delivery.disney-plus.net/v...             24: 레거시
# 4    https://prod-ripcut-delivery.disney-plus.net/v...         80년대 TOP 10
# ..                                                 ...                 ...
# 644  https://prod-ripcut-delivery.disney-plus.net/v...              사랑과 탄환
# 645  https://prod-ripcut-delivery.disney-plus.net/v...               제니메이션
# 646  https://prod-ripcut-delivery.disney-plus.net/v...  좀비스: 애디슨의 몬스터 미스터리
# 647  https://prod-ripcut-delivery.disney-plus.net/v...         더 존: 버텨야 산다
# 648  https://prod-ripcut-delivery.disney-plus.net/v...               주토피아+
#
#     series                             genre  \
# 0    시즌 1개       성장 스토리, 코미디, 애니메이션, 액션 어드벤처
# 1    시즌 1개                키즈, 애니메이션, 액션 어드벤처
# 2    시즌 8개  드라마, 경찰/형사, 스파이/첩보, 스릴러, 액션 어드벤처
# 3    시즌 1개  드라마, 경찰/형사, 스파이/첩보, 스릴러, 액션 어드벤처
# 4    시즌 1개                             다큐시리즈
# ..     ...                               ...
# 644  시즌 1개                      로맨스, 드라마, 범죄
# 645  시즌 2개                     가족, 연작, 애니메이션
# 646  시즌 1개              코미디, 판타지, 애니메이션, 뮤지컬
# 647  시즌 2개                     서바이벌, 게임 쇼/경쟁
# 648  시즌 1개                가족, 연작, 코미디, 애니메이션
#
#                                               overview         open  \
# 0    딜라일라와 더그의 장녀 돌리, 장남 딜런 남매와 97마리 동생들의 모험을 따라가 보...         2018
# 1    강아지들의 가죽으로 털 코트를 만들려던 크루엘라 드 빌의 계획을 저지한 디얼리 가족...         1997
# 2    `24'는 하루 동안 벌어지는 일이 전체 시즌을 이루는 독특한 시리즈물로, 총 24...  2001 - 2010
# 3    에미상 수상작 '24'의 진화된 버전 '24: 레거시'와 함께 시곗바늘이 다시 움직...         2017
# 4    롭 로가 80년대 팝 문화에서 가장 기억에 남는 10가지 순간을 돌아본다. 장난감,...         2022
# ..                                                 ...          ...
# 644  있는 그대로 자신을 사랑해 줄 남자친구를 찾고 있는 대학생 유리(바바 후미카). 위...         2022
# 645  월트 디즈니 애니메이션 스튜디오의 시대를 초월한 영화 장면들이 신나는 사운드스케이프...  2020 - 2021
# 646  핼러윈 가을 무도회를 주최하는 애디슨은 으스스한 재미를 더하기 위한 준비를 하고 있...         2021
# 647  전 세계를 덮친 팬데믹 으로부터 시작된 가상공간 시뮬레이션 《더 존: 버텨야 산다》...  2022 - 2023
# 648  여러 동물이 한데 어우러져 사는 꿈의 도시 주토피아. 오늘 이곳에선 또 어떤 흥미로...         2022
#
#                                                 actors runtime
# 0                         [조쉬브레너, 미카엘라디츠, 엘라케니온, 라샨스톤]     24분
# 1           [제프베넷, 크리스틴카바나, 타라채렌도프, 짐커밍스, 트레스맥닐, 샬롯레이]     23분
# 2                                       [조엘서노우,로버트코크란]     43분
# 3                                          [매니코토,에반카츠]     45분
# 4                                   [롭로우, MiaBankston]     43분
# ..                                                 ...     ...
# 644                                    [후루카와유타, 바바후미카]     24분
# 645                                           [데이비드베스]      5분
# 646  [멕도넬리, MiloManheim, 아리엘마틴, ChandlerKinney, Kyl...      3분
# 647                                    [유재석, 이광수, 권유리]     54분
# 648  [BonnieHunt, LeahLatham, AlanTudyk, MauriceLaM...      9분
#
# [649 rows x 8 columns]

# %%
display.to_csv("./disney_series.csv")
